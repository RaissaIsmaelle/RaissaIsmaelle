# %% [markdown]
# <a href="https://colab.research.google.com/github/RaissaIsmaelle/RaissaIsmaelle/blob/main/WebScrappingExercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install beautifulsoup4

# %%
# !pip install requests

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url="http://feeds.bbci.co.uk/news/rss.xml"

# %%
#importer le code de la page
reponse=requests.get(url)
soup = BeautifulSoup(reponse.text,"html.parser")
# Out:
# /usr/lib/python3.10/html/parser.py:170: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   k = self.parse_starttag(i)

# %%
items=soup.findAll('item')

# %%
item=items[0]

# %%
item.description.text
# Out:
# 'The former lawyer of Donald Trump says he organised cash for a Playboy model "at the direction" of his boss.'

# %%
news_items=[]

# %%
for i in items:
  news_i={}
  news_i['title']=i.title.text
  news_i['description']=i.description.text
  news_i['pubdate']=i.pubdate.text
  news_items.append(news_i)

# %%
news_items
# Out:
# [{'title': "Michael Cohen claims he paid hush money at Trump's direction",
#   'description': 'The former lawyer of Donald Trump says he organised cash for a Playboy model "at the direction" of his boss.',
#   'pubdate': 'Mon, 13 May 2024 12:39:50 GMT'},
#  {'title': "'Horrendous birth experience left me in therapy'",
#   'description': 'Hundreds of women have contacted BBC News with their traumatic experiences of giving birth.',
#   'pubdate': 'Mon, 13 May 2024 11:46:26 GMT'},
#  {'title': 'Military servicewoman says senior officer raped her',
#   'description': 'The woman says the alleged incident ended her career - but the male senior officer kept his job.',
#   'pubdate': 'Mon, 13 May 2024 14:19:06 GMT'},
#  {'title': 'Gazans flee as Israeli forces go back into Jabalia',
#   'description': 'Fierce fighting is reported as Israel says it is targeting areas of where Hamas has regrouped.',
#   'pubdate': 'Mon, 13 May 2024 15:51:20 GMT'},
# ...

# %%
df=pd.DataFrame(news_items, columns=['title','description','pubdate'])

# %%
df.head(35)
# Out:
#                                                 title  \
# 0   Michael Cohen claims he paid hush money at Tru...
# 1    'Horrendous birth experience left me in therapy'
# 2   Military servicewoman says senior officer rape...
# 3   Gazans flee as Israeli forces go back into Jab...
# 4       Melinda French Gates to quit Gates Foundation
# 5   Eurovision EU flag ban regrettable, Brussels says
# 6   Russia says troops enter border town near Kharkiv
# 7   Rwanda scheme: NI court ruling delivers blow t...
# 8   Power to move rough sleepers over 'smells' dro...
# 9   Trump VP hopeful outlawed in six Native Americ...
# 10  Mother and son jailed over XL bully attack on boy
# 11   King Charles hands over military role to William
# 12   Eurovision winner explains how they broke trophy
# 13  I lost my mum, dad and baby sister to HIV in i...
# 14   Gaza war weighs heavily on Israel's memorial day
# 15  How will Scotland's new first minister navigat...
# ...

# %%
df.tail()
# Out:
#                                                  title  \
# 139  Who gets 15 hours of free childcare and how do...
# 140  Mother and son jailed over XL bully attack on boy
# 141            Man sentenced for petrol station murder
# 142     Teenager admits killing three friends in crash
# 143           HMP Parc staff allegedly taking in drugs
#
#                                            description  \
# 139  Parents in England can now access 15 hours of ...
# 140  The dog caused the boy "catastrophic and life ...
# 141  Malcolm McKeown, 54, was shot as he sat in a c...
# 142  Jake Loy was driving the car in which his frie...
# 143  Parc prison has seen four deaths linked to sub...
#
#                            pubdate
# 139  Mon, 13 May 2024 09:06:26 GMT
# 140  Mon, 13 May 2024 15:57:26 GMT
# 141  Mon, 13 May 2024 12:44:47 GMT
# 142  Mon, 13 May 2024 13:51:12 GMT
# 143  Mon, 13 May 2024 16:38:37 GMT

# %%
df.to_csv('web_scrapping.cvs', index=False,encoding='utf-8')
